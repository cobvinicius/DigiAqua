# %% [markdown]
# <a href="https://colab.research.google.com/github/cobvinicius/DigiAqua/blob/main/BivalvesDectetionRoboflowDatasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.9/625.9 kB 17.0 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2CGU5AVKRT9vhSkeN257")
project = rf.workspace("usda").project("usda-shellfish")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.128, to fix: `pip install ultralytics<=8.0.20`
#
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to USDA-Shellfish-1 in yolov8:: 100%|██████████| 202/202 [00:00<00:00, 941.72it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/USDA-Shellfish-1/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 72.5MB/s]
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/Test3.jpg
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients
#
# image 1/1 /content/Test3.jpg: 288x640 26 closeds, 18 semi opens, 274.6ms
# Speed: 3.9ms preprocess, 274.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to runs/detect/predict3

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2CGU5AVKRT9vhSkeN257")
project = rf.workspace("shelldetection").project("new-shell")
dataset = project.version(5).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.128, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to New-Shell-5 in yolov8:: 100%|██████████| 2426/2426 [00:01<00:00, 1978.42it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/New-Shell-5/data.yaml epochs=50 imgsz=640
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 5, in <module>
#     from ultralytics.yolo.cfg import entrypoint
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/__init__.py", line 5, in <module>
#     from ultralytics.hub import start
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/hub/__init__.py", line 5, in <module>
#     from ultralytics.hub.auth import Auth
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/hub/auth.py", line 5, in <module>
#     from ultralytics.hub.utils import HUB_API_ROOT, PREFIX, request_with_credentials
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/hub/utils.py", line 14, in <module>
#     from ultralytics.yolo.utils import (ENVIRONMENT, LOGGER, ONLINE, RANK, SETTINGS, TESTS_RUNNING, TQDM_BAR_FORMAT,
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/__init__.py", line 3, in <module>
#     from . import v8
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/Test3.jpg
