# %% [markdown]
# <a href="https://colab.research.google.com/github/cobvinicius/DigiAqua/blob/main/BivalveDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Followed the Tutorial:
#  https://www.youtube.com/watch?v=_H4irxuLflA&ab_channel=TechwithDK

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.9/625.9 kB 34.9 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2CGU5AVKRT9vhSkeN257")
project = rf.workspace("digiaqua").project("bivalves-detection")
dataset = project.version(3).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.128, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Bivalves-Detection-3 in yolov8:: 100%|██████████| 54/54 [00:00<00:00, 1564.55it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/Bivalves-Detection-3/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train4/weights/best.pt conf=0.25 source=/content/Test.jpg
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/1 /content/Test.jpg: 320x640 12 Bivalves, 345.5ms
# Speed: 3.5ms preprocess, 345.5ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict
